# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from src.subtitle.SubtitleToStorage import SubtitlesToStorage
import pandas as pd
from tqdm import tqdm

tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
model = AutoModelForSeq2SeqLM.from_pretrained('facebook/bart-large-cnn')

videos = pd.read_csv('../data/videos/tom_scott_videos.csv')
generated_titles = list()
for _, row in tqdm(videos.iterrows(), total=videos.shape[0]):
    subtitle_downloader = SubtitlesToStorage(
        source='youtube',
        video_id=row['video_id'],
        storage_config={'type': 'return_value'}
    )

    subtitles = subtitle_downloader.save()
    batch = tokenizer(subtitles, truncation=True, max_length=1024, return_tensors='pt')
    generated_ids = model.generate(batch["input_ids"], min_length=256, max_length=512)
    summary = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    print(summary[0])
# Out:
#   0%|          | 1/241 [01:06<4:24:58, 66.25s/it]
# ["The South Terminal at London's Gatwick Airport will reopen to the public after nearly two years closed. The first flight from the South Terminal is scheduled to leave on Sunday morning. The South Terminal has been open for 60-odd years, but has been closed for the best part of two years. The airport is reopening 85% of it straight away, with the rest moving over from the North Terminal over three days. It is a huge task that we're undertaking, but we're feeling really confident, actually. The scale of what we're doing here is... we've often likened it toopening a smaller airport,completely from scratch. We've got a phased plan for our airlines moving back over from North Terminal, but all the infrastructure will comeonline more or less from day one. It will be about 3am when the first passengers go through the doors. And they probably won't know that the terminal was closed. They'll just want to get to their destination, even if they don't even know their destination. It's the biggest one I've done at Gatwick airport. I've never done anything like it before. I think it's fair to say, we all thought it'd be over in two weeks' time. But it's much more difficult than you might think."]
#   0%|          | 1/241 [01:35<6:21:21, 95.34s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 11>()
#      18 subtitles = subtitle_downloader.save()
#      19 batch = tokenizer(subtitles, truncation=True, max_length=1024, return_tensors='pt')
# ---> 20 generated_ids = model.generate(batch["input_ids"], min_length=256, max_length=512)
#      21 title = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
#      22 print(title)
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\transformers\generation_utils.py:1385, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1381     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1382         input_ids, expand_size=num_beams, is_encoder_decoder=self.config.is_encoder_decoder, **model_kwargs
#    1383     )
#    1384     # 12. run beam search
# -> 1385     return self.beam_search(
#    1386         input_ids,
#    1387         beam_scorer,
#    1388         logits_processor=logits_processor,
#    1389         stopping_criteria=stopping_criteria,
#    1390         pad_token_id=pad_token_id,
#    1391         eos_token_id=eos_token_id,
#    1392         output_scores=output_scores,
#    1393         return_dict_in_generate=return_dict_in_generate,
#    1394         synced_gpus=synced_gpus,
#    1395         **model_kwargs,
#    1396     )
#    1398 elif is_beam_sample_gen_mode:
#    1399     # 10. prepare logits warper
#    1400     logits_warper = self._get_logits_warper(
#    1401         top_k=top_k,
#    1402         top_p=top_p,
#    (...)
#    1406         renormalize_logits=renormalize_logits,
#    1407     )
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\transformers\generation_utils.py:2233, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2229         break
#    2231 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 2233 outputs = self(
#    2234     **model_inputs,
#    2235     return_dict=True,
#    2236     output_attentions=output_attentions,
#    2237     output_hidden_states=output_hidden_states,
#    2238 )
#    2240 if synced_gpus and this_peer_finished:
#    2241     cur_len = cur_len + 1
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\transformers\models\bart\modeling_bart.py:1359, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1354     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1355         decoder_input_ids = shift_tokens_right(
#    1356             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1357         )
# -> 1359 outputs = self.model(
#    1360     input_ids,
#    1361     attention_mask=attention_mask,
#    1362     decoder_input_ids=decoder_input_ids,
#    1363     encoder_outputs=encoder_outputs,
#    1364     decoder_attention_mask=decoder_attention_mask,
#    1365     head_mask=head_mask,
#    1366     decoder_head_mask=decoder_head_mask,
#    1367     cross_attn_head_mask=cross_attn_head_mask,
#    1368     past_key_values=past_key_values,
#    1369     inputs_embeds=inputs_embeds,
#    1370     decoder_inputs_embeds=decoder_inputs_embeds,
#    1371     use_cache=use_cache,
#    1372     output_attentions=output_attentions,
#    1373     output_hidden_states=output_hidden_states,
#    1374     return_dict=return_dict,
#    1375 )
#    1376 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1378 masked_lm_loss = None
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\transformers\models\bart\modeling_bart.py:1246, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1239     encoder_outputs = BaseModelOutput(
#    1240         last_hidden_state=encoder_outputs[0],
#    1241         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1242         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1243     )
#    1245 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1246 decoder_outputs = self.decoder(
#    1247     input_ids=decoder_input_ids,
#    1248     attention_mask=decoder_attention_mask,
#    1249     encoder_hidden_states=encoder_outputs[0],
#    1250     encoder_attention_mask=attention_mask,
#    1251     head_mask=decoder_head_mask,
#    1252     cross_attn_head_mask=cross_attn_head_mask,
#    1253     past_key_values=past_key_values,
#    1254     inputs_embeds=decoder_inputs_embeds,
#    1255     use_cache=use_cache,
#    1256     output_attentions=output_attentions,
#    1257     output_hidden_states=output_hidden_states,
#    1258     return_dict=return_dict,
#    1259 )
#    1261 if not return_dict:
#    1262     return decoder_outputs + encoder_outputs
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\FH Technikum Wien\Studium\Semester 2\Development Project 1\scientificProject\venv\lib\site-packages\transformers\models\bart\modeling_bart.py:1022, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1020     input = input_ids
#    1021     input_shape = input.shape
# -> 1022     input_ids = input_ids.view(-1, input_shape[-1])
#    1023 elif inputs_embeds is not None:
#    1024     input_shape = inputs_embeds.size()[:-1]
#
# KeyboardInterrupt:
